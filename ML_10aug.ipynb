# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print( df.shape )
# Out:
# (891, 15)

# %%
df_copy1 = df.copy()

# %%
df_encoded = pd.get_dummies( df_copy1, columns=["embarked"] )
#one hot encoding has been added for the "embarked" columns
#"embarked" feature has been removed

# %%
df_encoded.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#    adult_male deck  embark_town alive  alone  embarked_C  embarked_Q  \
# 0        True  NaN  Southampton    no  False       False       False
# 1       False    C    Cherbourg   yes  False        True       False
# 2       False  NaN  Southampton   yes   True       False       False
# 3       False    C  Southampton   yes  False       False       False
# 4        True  NaN  Southampton    no   True       False       False
#
#    embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
print( df_encoded.shape )
# Out:
# (891, 17)

# %%
df_copy2 = df.copy()

# %%
df_encoded_2 = pd.get_dummies( df_copy2, columns=["embarked"], drop_first = True )
#one hot encoding has been added for the "embarked" columns
#"embarked" feature has been removed
#"embarked_C" is not a feature in this dataframe

# %%
df_encoded_2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#    adult_male deck  embark_town alive  alone  embarked_Q  embarked_S
# 0        True  NaN  Southampton    no  False       False        True
# 1       False    C    Cherbourg   yes  False       False       False
# 2       False  NaN  Southampton   yes   True       False        True
# 3       False    C  Southampton   yes  False       False        True
# 4        True  NaN  Southampton    no   True       False        True

# %%
print( df_encoded_2.shape )
# Out:
# (891, 16)

# %%
df_copy3 = df.copy()

# %%
df_who = pd.get_dummies( df_copy3, columns=["who"] )

# %%
df_who.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone  who_child  who_man  who_woman
# 0        True  NaN  Southampton    no  False      False     True      False
# 1       False    C    Cherbourg   yes  False      False    False       True
# 2       False  NaN  Southampton   yes   True      False    False       True
# 3       False    C  Southampton   yes  False      False    False       True
# 4        True  NaN  Southampton    no   True      False     True      False

# %%
print( df_who.shape )
# Out:
# (891, 17)

# %%
df_copy4 = df.copy()

# %%
df_class = pd.get_dummies( df_copy4, columns=["class"] )

# %%
df_class.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone  class_First  class_Second  \
# 0        True  NaN  Southampton    no  False        False         False
# 1       False    C    Cherbourg   yes  False         True         False
# 2       False  NaN  Southampton   yes   True        False         False
# 3       False    C  Southampton   yes  False         True         False
# 4        True  NaN  Southampton    no   True        False         False
#
#    class_Third
# 0         True
# 1        False
# 2         True
# 3        False
# ...

# %%
print( df_class.shape )
# Out:
# (891, 17)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df_copy5 = df.copy()

# %%
encoder = OrdinalEncoder( categories=[ ["Third", "Second", "First"] ]  )

# %%
df_copy5[ "class_encoded" ] = encoder.fit_transform( df[ ["class"] ] )

# %%
df_copy5.head()

# %%
print( df_copy5.shape )
# Out:
# (891, 17)
